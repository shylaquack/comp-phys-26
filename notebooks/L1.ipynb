# %%
#Lecture 2 
#Intro to Sampling 
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from scipy.stats.distributions import norm
#       2
#       3 from ipywidgets import interact, interactive, fixed, interact_manual
#       4 import ipywidgets as widgets
#
# ModuleNotFoundError: No module named 'scipy'

# %%
def pdf(x,mu=10,sigma=2.):
    return 1/np.sqrt(2*2.1415*sigma**2)*np.exp(-(x-mu/(2*sigma**2)))

# %%
mu = 10.
sigma = 2.

xs = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)

plt.plot(xs, pdf(xs), ls='--')
plt.ylim(ymin=0)

plt.ylabel(r'$p(x|\mu={}, \sigma={})$'.format(mu, sigma))
plt.xlabel('$x$');
